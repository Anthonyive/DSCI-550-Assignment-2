# %%
import json
import pandas as pd

# %%
# !pip3 install pandas
# Out:
# ...
#      |████████████████████████████████| 10.4 MB 3.9 MB/s eta 0:00:01
# ...
#   Using cached pytz-2021.1-py2.py3-none-any.whl (510 kB)
# ...
# WARNING: You are using pip version 20.1.1; however, version 21.0.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.7/bin/python3.7 -m pip install --upgrade pip' command.

# %%
df = pd.read_json("LA_res.json")

# %%
df
# Out:
#                           id  \
# 0     RYpJyi1RhScLZAYrqPMLKQ
# 1     PyivZWrHyYv4JQd9qGGrjw
# 2     spKUIFIABLaU63Ex4PEYvQ
# 3     iKn3cdBPI9o2KNAJ4OHvLQ
# 4     IAzVa3gaOGeIKttZqphD2g
# ...                      ...
# 7441  Nd2kPs7KJsCo6gA_Yio6vw
# 7442  yBM7Lxe2lpkCegpvbh51tA
# 7443  JzDsQ_zz7TBf4vGCiz4IrA
# 7444  agPF3hNQaiHaNi-8hgiyiQ
# 7445  PezgFcp9dNrY9BxSSpPZtQ
#
#                                                   alias  \
# 0     avilas-el-ranchito-mexican-restaurant-huntingt...
# 1     tokyo-style-food-truck-and-catering-los-angeles-2
# 2                            rays-bbq-huntington-park-4
# 3       the-los-angeles-banh-mi-company-huntington-park
# 4                          teddys-red-tacos-los-angeles
# ...                                                 ...
# 7441                         tacos-el-superior-palmdale
# 7442                         blackbird-airpark-palmdale
# 7443               joe-davies-heritage-airpark-palmdale
# ...

# %%
res_df = df.loc[:,["id","name","review_count","categories","rating","coordinates","price","location"]]

# %%
res_df
# Out:
#                           id                                    name  \
# 0     RYpJyi1RhScLZAYrqPMLKQ  Avila's El Ranchito Mexican Restaurant
# 1     PyivZWrHyYv4JQd9qGGrjw     Tokyo Style Food Truck and Catering
# 2     spKUIFIABLaU63Ex4PEYvQ                                Rays BBQ
# 3     iKn3cdBPI9o2KNAJ4OHvLQ         The Los Angeles Banh Mi Company
# 4     IAzVa3gaOGeIKttZqphD2g                       Teddy's Red Tacos
# ...                      ...                                     ...
# 7441  Nd2kPs7KJsCo6gA_Yio6vw                       Tacos El Superior
# 7442  yBM7Lxe2lpkCegpvbh51tA                       Blackbird Airpark
# 7443  JzDsQ_zz7TBf4vGCiz4IrA             Joe Davies Heritage Airpark
# 7444  agPF3hNQaiHaNi-8hgiyiQ                           Tacos El Afro
# 7445  PezgFcp9dNrY9BxSSpPZtQ                             Ventura BBQ
#
#       review_count                                         categories  rating  \
# ...

# %%
res_dict = res_df.to_json(orient="records")

# %%
res_dict = (json.loads(res_dict))

# %%
with open("res.json","w")as f:
    json.dump(res_dict,f)
