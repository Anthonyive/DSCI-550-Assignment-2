# %%
# authenticate user (put this in a separate cell)
from google.colab import auth
auth.authenticate_user()

# %%
! pip install -r requirements-tpu.txt

# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 1.14.0

# %%
# setup the bucket to colab (put this in another cell)
import json
import os
import pprint
import re
import time
use_tpu = True #@param {type:"boolean"}
bucket = 'grover-task-jessica' #@param {type:"string"}
assert bucket, 'Must specify an existing GCS bucket name'
print('Using bucket: {}'.format(bucket))
if use_tpu:
    assert 'COLAB_TPU_ADDR' in os.environ, 'Missing TPU; did you request a TPU in Notebook Settings?'
DATA_DIR = 'gs://{}/{}'.format(bucket, time.strftime('tpuestimator-lstm/%Y-%m-%d-%H-%M-%S'))
print('Using data dir: {}'.format(DATA_DIR))
from google.colab import auth
auth.authenticate_user()
if 'COLAB_TPU_ADDR' in os.environ:
  TF_MASTER = 'grpc://{}'.format(os.environ['COLAB_TPU_ADDR'])
  print(TF_MASTER)
#Upload credentials to TPU.
  with tf.Session(TF_MASTER) as sess:    
    with open('/content/adc.json', 'r') as f:
      auth_info = json.load(f)
    tf.contrib.cloud.configure_gcs(sess, credentials=auth_info)
  # Now credentials are set for all future sessions on this TPU.
else:
  TF_MASTER=''
with tf.Session(TF_MASTER) as session:
  pprint.pprint(session.list_devices())
# Out:
# Using bucket: grover-task-jessica
# Using data dir: gs://grover-task-jessica/tpuestimator-lstm/2021-04-08-06-35-02
# grpc://10.43.227.2:8470
# [_DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:CPU:0, CPU, -1, 16800269880633301349),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 8589934592, 8896629314313455401),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 7414725650792643813),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 7063079093583556926),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 15573656794916628268),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 16740118112695682754),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 3926308575356154820),
# ...

# %%
# use TPU to do the job
import os
try:
  device_name = os.environ['COLAB_TPU_ADDR']
  TPU_ADDRESS = 'grpc://' + device_name
  print('Found TPU at: {}'.format(TPU_ADDRESS))
except KeyError:
  print('TPU not found')
# Out:
# Found TPU at: grpc://10.43.227.2:8470

# %% [markdown]
# My TPU ADDRESS: grpc://10.43.227.2:8470

# %% [markdown]
# `!python ~/path_to_run_discrimination_script_parent_directory/run_discrimination.py --input_data=./path_to_your_input_data_parent_directory/part8_inputs_total.jsonl --output_dir=gs://YOUR_BUCKET_NAME/outputs --config_file=./path_to_lm_folder_parent_directory/lm/configs/base.json --do_train=True --use_tpu=True --tpu_name=YOUR_TPU_DEVICE_ADDRESS_STARTING_WITH_grpc`

# %%
#! export PYTHONPATH="${PYTHONPATH}:/content/grover"

# %%
#clone github
# !pwd
# !git clone https://github.com/JessicaJiang98/grover.git
# Out:
# /content
# fatal: destination path 'grover' already exists and is not an empty directory.

# %%
! pwd
# Out:
# /content

# %%
# !python grover/discrimination/run_discrimination.py --input_data=grover/input_emails.jsonl --output_dir=gs://grover-task-jessica-jiang/outputs --config_file=grover/lm/configs/base.json --do_train=True --use_tpu=True --tpu_name=grpc://10.43.227.2:8470
# Out:
# WARNING:tensorflow:From /content/grover/lm/optimization_adafactor.py:88: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From grover/discrimination/run_discrimination.py:341: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From grover/discrimination/run_discrimination.py:142: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W0408 07:10:08.978008 140321538926464 deprecation_wrapper.py:119] From grover/discrimination/run_discrimination.py:142: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From grover/discrimination/run_discrimination.py:142: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# ...

# %% [markdown]
# run discrimination on the 800 generated email texts

# %%
# !python grover/discrimination/run_discrimination.py --input_data=grover/test_input.jsonl --output_dir=gs://grover-task-jessica-jiang/outputs --config_file=grover/lm/configs/base.json --do_train=False --predict_test=True --use_tpu=True --tpu_name=grpc://10.43.227.2:8470
# Out:
# WARNING:tensorflow:From /content/grover/lm/optimization_adafactor.py:88: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From grover/discrimination/run_discrimination.py:341: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From grover/discrimination/run_discrimination.py:142: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W0408 08:13:45.133348 139636565632896 deprecation_wrapper.py:119] From grover/discrimination/run_discrimination.py:142: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From grover/discrimination/run_discrimination.py:142: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# ...

# %%
# !python grover/discrimination/run_discrimination.py --input_data=grover/test_input.jsonl --output_dir=gs://grover-task-jessica-jiang/outputs --config_file=grover/lm/configs/base.json --do_train=False --predict_test=True --use_tpu=True --tpu_name=grpc://10.43.227.2:8470
# Out:
# WARNING:tensorflow:From /content/grover/lm/optimization_adafactor.py:88: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From grover/discrimination/run_discrimination.py:341: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From grover/discrimination/run_discrimination.py:142: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W0408 08:57:27.632302 140227477604224 deprecation_wrapper.py:119] From grover/discrimination/run_discrimination.py:142: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From grover/discrimination/run_discrimination.py:142: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# ...

# %%
# !python grover/discrimination/run_discrimination.py --input_data=grover/test_file.jsonl --output_dir=gs://grover-task-jessica-jiang/outputs --config_file=grover/lm/configs/base.json --do_train=False --predict_test=True --use_tpu=True --tpu_name=grpc://10.43.227.2:8470
# Out:
# WARNING:tensorflow:From /content/grover/lm/optimization_adafactor.py:88: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From grover/discrimination/run_discrimination.py:341: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From grover/discrimination/run_discrimination.py:142: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W0408 09:12:15.148811 139781536593792 deprecation_wrapper.py:119] From grover/discrimination/run_discrimination.py:142: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From grover/discrimination/run_discrimination.py:142: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# ...

# %%
# !python grover/discrimination/run_discrimination.py --input_data=grover/input_emails.jsonl --output_dir=gs://grover-task-jessica-jiang/output --config_file=grover/lm/configs/base.json --do_train=True --predict_test=False --use_tpu=True --tpu_name=grpc://10.43.227.2:8470
# Out:
# WARNING:tensorflow:From /content/grover/lm/optimization_adafactor.py:88: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From grover/discrimination/run_discrimination.py:341: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From grover/discrimination/run_discrimination.py:142: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W0408 09:49:01.962090 139721056036736 deprecation_wrapper.py:119] From grover/discrimination/run_discrimination.py:142: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From grover/discrimination/run_discrimination.py:142: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# ...

# %%
# !python grover/discrimination/run_discrimination.py --input_data=grover/test_input_human.jsonl --output_dir=gs://grover-task-jessica-jiang/output --config_file=grover/lm/configs/base.json --do_train=False --predict_test=True --use_tpu=True --tpu_name=grpc://10.43.227.2:8470
# Out:
# WARNING:tensorflow:From /content/grover/lm/optimization_adafactor.py:88: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From grover/discrimination/run_discrimination.py:341: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From grover/discrimination/run_discrimination.py:142: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W0408 10:23:43.160790 140015734839168 deprecation_wrapper.py:119] From grover/discrimination/run_discrimination.py:142: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From grover/discrimination/run_discrimination.py:142: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# ...

# %%
import numpy as np
result=np.load('/content/grover/test_result/output_test-probs_5.npy')

# %%
a=0
for entry in result:
  print(entry)
  if entry[1]>0.9:
    a=a+1
print(a)
# Out:
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# [0.9933362  0.00666374]
# ...

# %% [markdown]
# below code are trail and error

# %% [markdown]
# `!python ~/path_to_run_discrimination_script_parent_directory/run_discrimination.py --input_data=./path_to_your_input_data_parent_directory/part8_inputs_total.jsonl --output_dir=gs://YOUR_BUCKET_NAME/outputs --config_file=./path_to_lm_folder_parent_directory/lm/configs/base.json --do_train=True --use_tpu=True --tpu_name=YOUR_TPU_DEVICE_ADDRESS_STARTING_WITH_grpc`

# %% [markdown]
# service-[PROJECT_NUMBER]@cloud-tpu.iam.gserviceaccount.com
#
# As stated in the public documentation in order to find the service account of your Colab TPU you just need to replace the project number in the following mail address:
